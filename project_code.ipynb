# %%
import numpy as np
import pandas as pd

import scipy.stats as sts
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/gulshatkd/Python-project-Hotel-Reservations/main/hotel_revenue_historical_full.csv'
df = pd.read_csv(url)

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            1         85               2018               July
# 1  Resort Hotel            1         75               2018               July
# 2  Resort Hotel            1         23               2018               July
# 3  Resort Hotel            1         60               2018               July
# 4  Resort Hotel            1         96               2018               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     3       2  ...    No Deposit
# ...

# %%
# !pip install gitpython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from git import Repo

# клонируем репозиторий в папку repo
repo = Repo.clone_from("https://github.com/gulshatkd/Python-project-Hotel-Reservations.git", "repo")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1804f39b-7ca9-4e0a-8ad6-3f9b2f98eabd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1804f39b-7ca9-4e0a-8ad6-3f9b2f98eabd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# сохраняем файл в папке repo
for filename in uploaded.keys():
  with open("repo/" + filename, "wb") as f:
    f.write(uploaded[filename])

# %%
from git import Repo

# добавляем файл в индекс git
repo.index.add(["Код_проекта"])

# коммитим изменения
repo.index.commit("добавлен файл Код_проекта")

# отправляем изменения на GitHub с указанием учетных данных пользователя
origin = repo.remote(name="origin")
origin.push(username="gulshatkd", password="Kudabaeva20")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-1d8def429a60> in <cell line: 4>()
#       2
#       3 # добавляем файл в индекс git
# ----> 4 repo.index.add(["Код_проекта"])
#       5
#       6 # коммитим изменения
#
# /usr/local/lib/python3.9/dist-packages/git/index/base.py in add(self, items, force, fprogress, path_rewriter, write, write_extension_data)
#     813         # If there are no paths, the rewriter has nothing to do either
#     814         if paths:
# --> 815             entries_added.extend(self._entries_for_paths(paths, path_rewriter, fprogress, entries))
#     816
#     817         # HANDLE ENTRIES
#
# /usr/local/lib/python3.9/dist-packages/git/util.py in wrapper(self, *args, **kwargs)
#     142             raise InvalidGitRepositoryError("Method '%s' cannot operate on bare repositories" % func.__name__)
#     143         # END bare method
# ...
